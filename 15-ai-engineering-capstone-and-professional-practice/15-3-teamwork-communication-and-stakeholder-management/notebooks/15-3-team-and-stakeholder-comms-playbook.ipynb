# %% [markdown]
# # Lesson 15.3 - Teamwork & Communication (playbook notebook)
#
# This notebook provides reusable communication templates and scenario drills for capstone collaboration and stakeholder alignment.

# %% [markdown]
# ## Objectives
#
# - Use practical communication templates during execution.
# - Resolve common teamwork and stakeholder issues systematically.
# - Build professional communication artifacts for final assessment.

# %% [markdown]
# ## Weekly Status Update Template
#
# **Completed this week**
# -
#
# **In progress**
# -
#
# **Blockers/Risks**
# -
#
# **Decisions needed**
# -
#
# **Next week commitments (owner + date)**
# -

# %% [markdown]
# ## Stakeholder Meeting Notes Template
#
# - Date / Attendees
# - Objective
# - Key updates
# - Questions raised
# - Decisions made
# - Action items (owner, deadline)
# - Open risks

# %% [markdown]
# ## Decision Log Template
#
# | Date | Decision | Options | Chosen | Rationale | Owner |
# |---|---|---|---|---|---|
# | YYYY-MM-DD |  |  |  |  |  |

# %%
import pandas as pd

sample_decisions = pd.DataFrame(
    [
        {
            "date": "2026-07-03",
            "decision": "Use batch scoring for MVP",
            "options": "online API, batch job",
            "chosen": "batch job",
            "rationale": "timeline fit",
            "owner": "MLOps lead",
        },
        {
            "date": "2026-07-10",
            "decision": "Model choice",
            "options": "xgboost, logistic regression",
            "chosen": "xgboost",
            "rationale": "better F1 at acceptable latency",
            "owner": "ML lead",
        },
    ]
)

sample_decisions
# Out:
#          date                   decision                       options  \
# 0  2026-07-03  Use batch scoring for MVP         online API, batch job
# 1  2026-07-10               Model choice  xgboost, logistic regression
#
#       chosen                        rationale       owner
# 0  batch job                     timeline fit  MLOps lead
# 1    xgboost  better F1 at acceptable latency     ML lead

# %% [markdown]
# ## Scenario Exercises
#
# ### Scenario 1: Scope Creep
# A mentor requests major feature additions two weeks before demo.
#
# Response: clarify value, estimate effort/risk, reprioritize must/should/could, confirm in writing.
#
# ### Scenario 2: Team Priority Conflict
# Disagreement between innovation and delivery stability.
#
# Response: map options to success criteria, log decision, assign owner.
#
# ### Scenario 3: Unclear Requirements
# Stakeholder asks to “make it smarter”.
#
# Response: convert to measurable criteria and validate acceptance threshold.

# %% [markdown]
# ## Capstone & Practice Case Studies & Exceptions
#
# ### Case Study A: Strong Tech, Weak Communication
# Good model quality but weak decision records hurt final defense.
#
# ### Case Study B: Simpler Tech, Strong Communication
# Clear updates and scope control led to better final assessment.
#
# ### Exception Pattern
# Solo projects still require communication discipline with mentors/reviewers.

# %% [markdown]
# ## Interview Questions & Answers
#
# 1. **Q:** How did you manage team coordination?
#    **A:** Weekly updates, role ownership, and decision logs.
# 2. **Q:** How did you handle conflicting priorities?
#    **A:** Mapped options to success criteria and explicit trade-offs.
# 3. **Q:** What communication artifact was most useful?
#    **A:** Weekly update with blockers and action owners.
# 4. **Q:** How did you manage stakeholder expectations?
#    **A:** Clear acceptance criteria and regular cadence updates.
# 5. **Q:** How do you explain technical debt to non-technical stakeholders?
#    **A:** Translate debt into delivery and reliability risk.
# 6. **Q:** How did you prevent scope creep?
#    **A:** Formal change review using must/should/could.
# 7. **Q:** Why keep meeting notes?
#    **A:** They preserve decisions and accountability.
# 8. **Q:** How did you resolve team conflict?
#    **A:** Criteria-based decisions and role clarity.
# 9. **Q:** Why include ethics in updates?
#    **A:** Stakeholders need risk visibility, not just metrics.
# 10. **Q:** What process change would you make next time?
#     **A:** Earlier escalation and tighter milestone reviews.
# 11. **Q:** How does this help interviews?
#     **A:** It shows leadership and collaboration evidence.

# %% [markdown]
# ## Communication Rubric Worksheet
# Rate each category (1-5):
#
# - Role clarity and ownership
# - Stakeholder alignment quality
# - Decision-log discipline
# - Risk escalation effectiveness
# - Demo/presentation communication

# %% [markdown]
# ## Team Reflection Prompts
# 1. What communication pattern prevented rework?
# 2. What misunderstanding caused the highest delay?
# 3. What one process change improves the next capstone cycle?
